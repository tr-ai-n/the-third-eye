# %%
from face_rec import f_rec

# %%
f_rec.return_known_name('face_rec/face/1.jpg')
# Out:
# embedding face
# starting video...
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# [DEBUG] KNOWN FACE DETECTED:  Shashwat
# ...
